# %% [markdown]
# # Day 65 - Llm generationn & Monitoring using mlflow and prometheus
#  ## what we will have after today : we will be able to generate response from the llm and track the different parameter using mlflow

# %% [markdown]
# # IMPorts

# %%
import time
import numpy as np
import chromadb
from sentence_transformers import SentenceTransformer
from rank_bm25 import BM25Okapi
from groq import Groq
import mlflow
from prometheus_client import Counter, Histogram, Gauge, generate_latest, CONTENT_TYPE_LATEST
from day64_rag_pipeline_clean import expand_financial_query, retreive_with_citations , enriched_texts, chunks, citation_formatted_answer

# %% [markdown]
# # Prometheus parameter

# %%
rag_requests_total = Counter(
    "rag_requests_total", 
    "Total RAG API requests", 
    ["endpoint", "status_code"]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 rag_requests_total = Counter(
#       2     "rag_requests_total",
#       3     "Total RAG API requests",
#       4     ["endpoint", "status_code"]
#       5 )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/metrics.py:136, in MetricWrapperBase.__init__(self, name, documentation, labelnames, namespace, subsystem, unit, registry, _labelvalues)
#     133 if not self._labelvalues:
#     134     # Register the multi-wrapper parent metric, or if a label-less metric, the whole shebang.
#     135     if registry:
# --> 136         registry.register(self)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/registry.py:43, in CollectorRegistry.register(self, collector)
#      41 duplicates = set(self._names_to_collectors).intersection(names)
#      42 if duplicates:
# ---> 43     raise ValueError(
#      44         'Duplicated timeseries in CollectorRegistry: {}'.format(
#      45             duplicates))
#      46 for name in names:
#      47     self._names_to_collectors[name] = collector
#
# ValueError: Duplicated timeseries in CollectorRegistry: {'rag_requests', 'rag_requests_created', 'rag_requests_total'}

# %%
pipeline_duration_seconds = Histogram(
    "pipeline_duration_seconds", 
    "Latency of the RAG pipeline in seconds", 
    ["endpoint"],
    buckets=[0.25, 0.5, 1.0, 2.0, 3.0, 5.0, 10.0]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 pipeline_duration_seconds = Histogram(
#       2     "pipeline_duration_seconds",
#       3     "Latency of the RAG pipeline in seconds",
#       4     ["endpoint"],
#       5     buckets=[0.25, 0.5, 1.0, 2.0, 3.0, 5.0, 10.0]
#       6 )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/metrics.py:626, in Histogram.__init__(self, name, documentation, labelnames, namespace, subsystem, unit, registry, _labelvalues, buckets)
#     614 def __init__(self,
#     615              name: str,
#     616              documentation: str,
#    (...)
#     623              buckets: Sequence[Union[float, str]] = DEFAULT_BUCKETS,
#     624              ):
#     625     self._prepare_buckets(buckets)
# --> 626     super().__init__(
#     627         name=name,
#     628         documentation=documentation,
#     629         labelnames=labelnames,
#     630         namespace=namespace,
#     631         subsystem=subsystem,
#     632         unit=unit,
#     633         registry=registry,
#     634         _labelvalues=_labelvalues,
#     635     )
#     636     self._kwargs['buckets'] = buckets
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/metrics.py:136, in MetricWrapperBase.__init__(self, name, documentation, labelnames, namespace, subsystem, unit, registry, _labelvalues)
#     133 if not self._labelvalues:
#     134     # Register the multi-wrapper parent metric, or if a label-less metric, the whole shebang.
#     135     if registry:
# --> 136         registry.register(self)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/registry.py:43, in CollectorRegistry.register(self, collector)
#      41 duplicates = set(self._names_to_collectors).intersection(names)
#      42 if duplicates:
# ---> 43     raise ValueError(
#      44         'Duplicated timeseries in CollectorRegistry: {}'.format(
#      45             duplicates))
#      46 for name in names:
#      47     self._names_to_collectors[name] = collector
#
# ValueError: Duplicated timeseries in CollectorRegistry: {'pipeline_duration_seconds_count', 'pipeline_duration_seconds_created', 'pipeline_duration_seconds_bucket', 'pipeline_duration_seconds_sum', 'pipeline_duration_seconds'}

# %%
active_processing_queries = Gauge(
    "active_processing_queries", 
    "Number of currently processing RAG queries"
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 active_processing_queries = Gauge(
#       2     "active_processing_queries",
#       3     "Number of currently processing RAG queries"
#       4 )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/metrics.py:425, in Gauge.__init__(self, name, documentation, labelnames, namespace, subsystem, unit, registry, _labelvalues, multiprocess_mode)
#     423 if multiprocess_mode not in self._MULTIPROC_MODES:
#     424     raise ValueError('Invalid multiprocess mode: ' + multiprocess_mode)
# --> 425 super().__init__(
#     426     name=name,
#     427     documentation=documentation,
#     428     labelnames=labelnames,
#     429     namespace=namespace,
#     430     subsystem=subsystem,
#     431     unit=unit,
#     432     registry=registry,
#     433     _labelvalues=_labelvalues,
#     434 )
#     435 self._kwargs['multiprocess_mode'] = self._multiprocess_mode
#     436 self._is_most_recent = self._multiprocess_mode in self._MOST_RECENT_MODES
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/metrics.py:136, in MetricWrapperBase.__init__(self, name, documentation, labelnames, namespace, subsystem, unit, registry, _labelvalues)
#     133 if not self._labelvalues:
#     134     # Register the multi-wrapper parent metric, or if a label-less metric, the whole shebang.
#     135     if registry:
# --> 136         registry.register(self)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/prometheus_client/registry.py:43, in CollectorRegistry.register(self, collector)
#      41 duplicates = set(self._names_to_collectors).intersection(names)
#      42 if duplicates:
# ---> 43     raise ValueError(
#      44         'Duplicated timeseries in CollectorRegistry: {}'.format(
#      45             duplicates))
#      46 for name in names:
#      47     self._names_to_collectors[name] = collector
#
# ValueError: Duplicated timeseries in CollectorRegistry: {'active_processing_queries'}

# %% [markdown]
# # MlFlow

# %%
import os

# %%
chroma_client = chromadb.PersistentClient(path="./chroma_db/")
collection = chroma_client.get_collection(name="financial_docs_v2")
count = collection.count()

# %%
# Check the first chunk's metadata keys
if len(chunks) > 0:
    print(f"Available metadata keys: {chunks[0]['metadata'].keys()}")
    print(f"Sample metadata: {chunks[0]['metadata']}")
# Out:
# Available metadata keys: dict_keys(['doc_type', 'source_file', 'quality_score', 'fiscal_year', 'chunk_id', 'section_num', 'section_title', 'company'])
# Sample metadata: {'doc_type': '10-K', 'source_file': 'aapl-20230930.htm', 'quality_score': 0.222, 'fiscal_year': 'FY2023', 'chunk_id': 'apple_inc._FY2023_s012', 'section_num': 12, 'section_title': 'PART I', 'company': 'Apple Inc.'}

# %%
if 'collection' in locals() and collection.count() > 0:
    db_data = collection.get(include=['documents', 'metadatas'])
    
    chunks = []
    for id_, text, meta in zip(db_data['ids'], db_data['documents'], db_data['metadatas']):
        sanitized_chunk = {
            "chunk_id": id_,
            "text": text,
            "company": meta.get("company", "Unknown Company"),
            "doc_type": meta.get("doc_type", "Document"),
            "fiscal_year": meta.get("fiscal_year", "N/A"),
            "section_title": meta.get("section_title", "General Section"),
            "metadata": meta # Keep for reference
        }
        
        for key, value in meta.items():
            if key not in sanitized_chunk:
                sanitized_chunk[key] = value
                
        chunks.append(sanitized_chunk)
    
    enriched_texts = db_data['documents']
    
    # Re-initialize BM25 with the cleaned texts
    tokenized_corpus = [doc.split(" ") for doc in enriched_texts]
    bm25 = BM25Okapi(tokenized_corpus)
    
    print(f"✅ Synced {len(chunks)} chunks. Defensive defaults applied to all keys.")
# Out:
# ✅ Synced 74 chunks. Defensive defaults applied to all keys.

# %%
embedding_model = SentenceTransformer("all-MiniLM-L6-v2")
# Out:
# Loading weights: 100%|█████████████████████████████████████████████████████████| 103/103 [00:00<00:00, 5465.96it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
API_KEY = "####"

# %%
groq_client = Groq(api_key=API_KEY)

# %%
mlflow.set_experiment("financial_rag_pipeline")
# Out:
# <Experiment: artifact_location='/home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlruns/1', creation_time=1777991309235, experiment_id='1', last_update_time=1777991309235, lifecycle_stage='active', name='financial_rag_pipeline', tags={}, trace_location=None, workspace='default'>

# %%
print("✅ Clients initialized and MLflow experiment set.")
# Out:
# ✅ Clients initialized and MLflow experiment set.

# %% [markdown]
# # Generate answer

# %%
def generate_answer(query: str) -> dict:
    """
    Orchestrates the full RAG pipeline: Expansion -> Retrieval -> Guardrail -> Generation.
    """
    start_time = time.time()
    
    # Query Expansion Prepare the query for numeric/tabular search
    expanded_query = expand_financial_query(query)
    chunk_texts = [chunk['text'] for chunk in chunks]
    tokenized_corpus = [doc.split(" ") for doc in chunk_texts]
    bm25 = BM25Okapi(tokenized_corpus)
    
    # Hybrid Retrieval Fetch relevant context from ChromaDB and BM25
    retrieved_results = retreive_with_citations(
        query=expanded_query, 
        bm25_index=bm25, 
        documents=enriched_texts, 
        chunks=chunks, 
        collection=collection,
        n_results=3,
        alpha=0.7
    )
    
    #  Guardrail Short-circuit if no relevant context is found
    if not retrieved_results:
        execution_time = (time.time() - start_time) * 1000
        return {
            "answer": "I'm sorry, I couldn't find any relevant financial data in the current documents to answer that.",
            "sources": [],
            "latency_ms": round(execution_time, 2)
        }
    
    # Prompt Assembly Using your Day 64 formatting function[cite: 1]
    # This transforms the results into the strict "[Source 1]" prompt format.
    prompt = citation_formatted_answer(query, retrieved_results)
    
    #  LLM Inference Groq execution with your assembled prompt
    chat_completion = groq_client.chat.completions.create(
        messages=[
            {
                "role": "system",
                "content": "You are a professional financial analyst. Use only the provided context."
            },
            {
                "role": "user",
                "content": prompt, 
            }
        ],
        model="llama-3.3-70b-versatile",
        temperature=0.1, 
        max_tokens=1024,
    )

    p_tokens = chat_completion.usage.prompt_tokens
    c_tokens = chat_completion.usage.completion_tokens
    
    answer = chat_completion.choices[0].message.content
    execution_time = (time.time() - start_time) * 1000
    
    # 6. Packaging Return structured response for the API
    return {
        "answer": answer,
        "sources": [
            {
                "chunk_id": r["chunk_id"],
                "citation": r["citation"],
                "hybrid_score": r["hybrid_score"]
            } for r in retrieved_results
        ],
        "latency_ms": round(execution_time, 2),
        "prompt_tokens": p_tokens,
        "completion_tokens": c_tokens
    }

# %% [markdown]
# # Monitoring the geneation

# %%
def generate_answer_with_monitoring(query: str) -> dict:
    active_processing_queries.inc()
    start_time = time.time()

    try:
        result = generate_answer(query)

        latency_sec = time.time() - start_time
        latency_ms = latency_sec * 1000

        sources = result.get("sources",[])
        top_hybrid_score = max([s["hybrid_score"] for s in sources]) if sources else 0.0

        # cost estimation 
        prompt_t = result.get("prompt_tokens",0)
        completion_t = result.get("completion_tokens",0)
        cost_estimate  = (prompt_t + completion_t) * 0.000030

        # Mlflow audit 
        with mlflow.start_run(run_name="rag_request"):
            mlflow.log_param("query",query)
            mlflow.log_metric("latency_ms",latency_ms)
            mlflow.log_metric("top_hybrid_score",top_hybrid_score)
            mlflow.log_metric("cost_estimate_usd",cost_estimate)

            mlflow.log_param("retrieved_chunk_ids",[s["chunk_id"] for s in sources])

        pipeline_duration_seconds.labels(endpoint="generate_answer").observe(latency_sec)
        rag_requests_total.labels(endpoint="generate_answer",status_code="success").inc()

        return result

    except Exception as e:
        rag_requests_total.labels(endpoint="generate_answer",status_code="error").inc()
        print(f"❌ Critical error in monitored pipeline: {str(e)}")
        raise e 

    finally:
        active_processing_queries.dec()

# %%
# --- Cell 7: Test Execution ---
test_query = "What was Apple's total revenue in 2023?"

print(f"🚀 Launching query: {test_query}\n" + "-"*50)

# Run the monitored pipeline
final_result = generate_answer_with_monitoring(test_query)

print(f"🤖 ANSWER:\n{final_result['answer']}\n")
print(f"⏱️ LATENCY: {final_result['latency_ms']} ms")
print(f"🔗 SOURCES: {[s['citation'] for s in final_result['sources']]}")
# Out:
# 🚀 Launching query: What was Apple's total revenue in 2023?
# --------------------------------------------------
# 2026/05/05 22:11:21 ERROR mlflow.store.db.utils: SQLAlchemy database error. The following exception is caught.
# (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO runs (run_uuid, name, source_type, source_name, entry_point_name, user_id, status, start_time, end_time, deleted_time, source_version, lifecycle_stage, artifact_uri, experiment_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('8d5a4adc38d9455d9d7ab8d46ae7980b', 'rag_request', 'UNKNOWN', '', '', 'spectra', 'RUNNING', 1777999281233, None, None, '', 'active', '/home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlruns/1/8d5a4adc38d9455d9d7ab8d46ae7980b/artifacts', '1')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1967, in _exec_single_context
#     self.dialect.do_execute(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 952, in do_execute
#     cursor.execute(statement, parameters)
# sqlite3.OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/db/utils.py", line 187, in make_managed_session
#     yield session
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 822, in create_run
#     inputs_list = self._get_run_inputs(session, [run_id])
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py", line 873, in _get_run_inputs
#     ).all()
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/query.py", line 2711, in all
#     return self._iter().all()  # type: ignore
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/query.py", line 2864, in _iter
#     result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 2351, in execute
#     return self._execute_internal(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 2228, in _execute_internal
#     ) = compile_state_cls.orm_pre_session_exec(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/context.py", line 577, in orm_pre_session_exec
#     session._autoflush()
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 3051, in _autoflush
#     raise e.with_traceback(sys.exc_info()[2])
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 3040, in _autoflush
#     self.flush()
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4331, in flush
#     self._flush(objects)
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4466, in _flush
#     with util.safe_reraise():
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py", line 121, in __exit__
#     raise exc_value.with_traceback(exc_tb)
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py", line 4427, in _flush
#     flush_context.execute()
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 466, in execute
#     rec.execute(self)
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py", line 642, in execute
#     util.preloaded.orm_persistence.save_obj(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 93, in save_obj
#     _emit_insert_statements(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py", line 1048, in _emit_insert_statements
#     result = connection.execute(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1419, in execute
#     return meth(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/sql/elements.py", line 527, in _execute_on_connection
#     return connection._execute_clauseelement(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1641, in _execute_clauseelement
#     ret = self._execute_context(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1846, in _execute_context
#     return self._exec_single_context(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1986, in _exec_single_context
#     self._handle_dbapi_exception(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 2363, in _handle_dbapi_exception
#     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py", line 1967, in _exec_single_context
#     self.dialect.do_execute(
#   File "/opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/default.py", line 952, in do_execute
#     cursor.execute(statement, parameters)
# sqlalchemy.exc.OperationalError: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO runs (run_uuid, name, source_type, source_name, entry_point_name, user_id, status, start_time, end_time, deleted_time, source_version, lifecycle_stage, artifact_uri, experiment_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('8d5a4adc38d9455d9d7ab8d46ae7980b', 'rag_request', 'UNKNOWN', '', '', 'spectra', 'RUNNING', 1777999281233, None, None, '', 'active', '/home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlruns/1/8d5a4adc38d9455d9d7ab8d46ae7980b/artifacts', '1')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ❌ Critical error in monitored pipeline: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO runs (run_uuid, name, source_type, source_name, entry_point_name, user_id, status, start_time, end_time, deleted_time, source_version, lifecycle_stage, artifact_uri, experiment_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('8d5a4adc38d9455d9d7ab8d46ae7980b', 'rag_request', 'UNKNOWN', '', '', 'spectra', 'RUNNING', 1777999281233, None, None, '', 'active', '/home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlruns/1/8d5a4adc38d9455d9d7ab8d46ae7980b/artifacts', '1')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: attempt to write a readonly database
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/db/utils.py:187, in _get_managed_session_maker.<locals>.make_managed_session()
#     186     session.execute(sql.text("PRAGMA case_sensitive_like = true;"))
# --> 187 yield session
#     188 session.commit()
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py:822, in SqlAlchemyStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     821 run = run.to_mlflow_entity()
# --> 822 inputs_list = self._get_run_inputs(session, [run_id])
#     823 dataset_inputs = inputs_list[0] if inputs_list else []
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py:873, in SqlAlchemyStore._get_run_inputs(self, session, run_uuids)
#     859 def _get_run_inputs(self, session, run_uuids):
#     860     datasets_with_tags = (
#     861         session
#     862         .query(
#     863             SqlInput.input_uuid,
#     864             SqlInput.destination_id.label("run_uuid"),
#     865             SqlDataset,
#     866             SqlInputTag,
#     867         )
#     868         .select_from(SqlInput)
#     869         .join(SqlDataset, SqlInput.source_id == SqlDataset.dataset_uuid)
#     870         .outerjoin(SqlInputTag, SqlInputTag.input_uuid == SqlInput.input_uuid)
#     871         .filter(SqlInput.destination_type == "RUN", SqlInput.destination_id.in_(run_uuids))
#     872         .order_by("run_uuid")
# --> 873     ).all()
#     875     dataset_inputs_per_run = defaultdict(dict)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2711, in Query.all(self)
#    2690 """Return the results represented by this :class:`_query.Query`
#    2691 as a list.
#    2692
#    (...)
#    2709     :meth:`_engine.Result.scalars` - v2 comparable method.
#    2710 """
# -> 2711 return self._iter().all()
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/query.py:2864, in Query._iter(self)
#    2863 statement = self._statement_20()
# -> 2864 result: Union[ScalarResult[_T], Result[_T]] = self.session.execute(
#    2865     statement,
#    2866     params,
#    2867     execution_options={"_sa_orm_load_options": self.load_options},
#    2868 )
#    2870 # legacy: automatically set scalars, unique
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2351, in Session.execute(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event)
#    2301 r"""Execute a SQL expression construct.
#    2302
#    2303 Returns a :class:`_engine.Result` object representing
#    (...)
#    2349
#    2350 """
# -> 2351 return self._execute_internal(
#    2352     statement,
#    2353     params,
#    2354     execution_options=execution_options,
#    2355     bind_arguments=bind_arguments,
#    2356     _parent_execute_state=_parent_execute_state,
#    2357     _add_event=_add_event,
#    2358 )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py:2228, in Session._execute_internal(self, statement, params, execution_options, bind_arguments, _parent_execute_state, _add_event, _scalar_result)
#    2219 if compile_state_cls is not None:
#    2220     # now run orm_pre_session_exec() "for real".   if there were
#    2221     # event hooks, this will re-run the steps that interpret
#    2222     # new execution_options into load_options / update_delete_options,
#    2223     # which we assume the event hook might have updated.
#    2224     # autoflush will also be invoked in this step if enabled.
#    2225     (
#    2226         statement,
#    2227         execution_options,
# -> 2228     ) = compile_state_cls.orm_pre_session_exec(
#    2229         self,
#    2230         statement,
#    2231         params,
#    2232         execution_options,
#    2233         bind_arguments,
#    2234         False,
#    2235     )
#    2237 bind = self.get_bind(**bind_arguments)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/context.py:577, in ORMCompileState.orm_pre_session_exec(cls, session, statement, params, execution_options, bind_arguments, is_pre_event)
#     576 if not is_pre_event and load_options._autoflush:
# --> 577     session._autoflush()
#     579 return statement, execution_options
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py:3051, in Session._autoflush(self)
#    3046 e.add_detail(
#    3047     "raised as a result of Query-invoked autoflush; "
#    3048     "consider using a session.no_autoflush block if this "
#    3049     "flush is occurring prematurely"
#    3050 )
# -> 3051 raise e.with_traceback(sys.exc_info()[2])
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py:3040, in Session._autoflush(self)
#    3039 try:
# -> 3040     self.flush()
#    3041 except sa_exc.StatementError as e:
#    3042     # note we are reraising StatementError as opposed to
#    3043     # raising FlushError with "chaining" to remain compatible
#    3044     # with code that catches StatementError, IntegrityError,
#    3045     # etc.
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4331, in Session.flush(self, objects)
#    4330     self._flushing = True
# -> 4331     self._flush(objects)
#    4332 finally:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4466, in Session._flush(self, objects)
#    4465 except:
# -> 4466     with util.safe_reraise():
#    4467         transaction.rollback(_capture_exception=True)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/util/langhelpers.py:121, in safe_reraise.__exit__(self, type_, value, traceback)
#     120     self._exc_info = None  # remove potential circular references
# --> 121     raise exc_value.with_traceback(exc_tb)
#     122 else:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/session.py:4427, in Session._flush(self, objects)
#    4426 try:
# -> 4427     flush_context.execute()
#    4428 finally:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:466, in UOWTransaction.execute(self)
#     465 for rec in topological.sort(self.dependencies, postsort_actions):
# --> 466     rec.execute(self)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/unitofwork.py:642, in SaveUpdateAll.execute(self, uow)
#     640 @util.preload_module("sqlalchemy.orm.persistence")
#     641 def execute(self, uow):
# --> 642     util.preloaded.orm_persistence.save_obj(
#     643         self.mapper,
#     644         uow.states_for_mapper_hierarchy(self.mapper, False, False),
#     645         uow,
#     646     )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:93, in save_obj(base_mapper, states, uowtransaction, single)
#      85     _emit_update_statements(
#      86         base_mapper,
#      87         uowtransaction,
#    (...)
#      90         update,
#      91     )
# ---> 93     _emit_insert_statements(
#      94         base_mapper,
#      95         uowtransaction,
#      96         mapper,
#      97         table,
#      98         insert,
#      99     )
#     101 _finalize_insert_update_commands(
#     102     base_mapper,
#     103     uowtransaction,
#    (...)
#     119     ),
#     120 )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/orm/persistence.py:1048, in _emit_insert_statements(base_mapper, uowtransaction, mapper, table, insert, bookkeeping, use_orm_insert_stmt, execution_options)
#    1046 multiparams = [rec[2] for rec in records]
# -> 1048 result = connection.execute(
#    1049     statement, multiparams, execution_options=execution_options
#    1050 )
#    1051 if bookkeeping:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1419, in Connection.execute(self, statement, parameters, execution_options)
#    1418 else:
# -> 1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/sql/elements.py:527, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     526         assert isinstance(self, Executable)
# --> 527     return connection._execute_clauseelement(
#     528         self, distilled_params, execution_options
#     529     )
#     530 else:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1641, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1633 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1634     dialect=dialect,
#    1635     compiled_cache=compiled_cache,
#    (...)
#    1639     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1640 )
# -> 1641 ret = self._execute_context(
#    1642     dialect,
#    1643     dialect.execution_ctx_cls._init_compiled,
#    1644     compiled_sql,
#    1645     distilled_parameters,
#    1646     execution_options,
#    1647     compiled_sql,
#    1648     distilled_parameters,
#    1649     elem,
#    1650     extracted_params,
#    1651     cache_hit=cache_hit,
#    1652 )
#    1653 if has_events:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:2363, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2362     assert sqlalchemy_exception is not None
# -> 2363     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2364 else:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/base.py:1967, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1966     if not evt_handled:
# -> 1967         self.dialect.do_execute(
#    1968             cursor, str_statement, effective_parameters, context
#    1969         )
#    1971 if self._has_events or self.engine._has_events:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/sqlalchemy/engine/default.py:952, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     951 def do_execute(self, cursor, statement, parameters, context=None):
# --> 952     cursor.execute(statement, parameters)
#
# OperationalError: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO runs (run_uuid, name, source_type, source_name, entry_point_name, user_id, status, start_time, end_time, deleted_time, source_version, lifecycle_stage, artifact_uri, experiment_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('8d5a4adc38d9455d9d7ab8d46ae7980b', 'rag_request', 'UNKNOWN', '', '', 'spectra', 'RUNNING', 1777999281233, None, None, '', 'active', '/home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlruns/1/8d5a4adc38d9455d9d7ab8d46ae7980b/artifacts', '1')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# The above exception was the direct cause of the following exception:
#
# MlflowException                           Traceback (most recent call last)
# Cell In[112], line 7
#       4 print(f"🚀 Launching query: {test_query}\n" + "-"*50)
#       6 # Run the monitored pipeline
# ----> 7 final_result = generate_answer_with_monitoring(test_query)
#       9 print(f"🤖 ANSWER:\n{final_result['answer']}\n")
#      10 print(f"⏱️ LATENCY: {final_result['latency_ms']} ms")
#
# Cell In[111], line 36, in generate_answer_with_monitoring(query)
#      34     rag_requests_total.labels(endpoint="generate_answer",status_code="error").inc()
#      35     print(f"❌ Critical error in monitored pipeline: {str(e)}")
# ---> 36     raise e
#      38 finally:
#      39     active_processing_queries.dec()
#
# Cell In[111], line 20, in generate_answer_with_monitoring(query)
#      17 cost_estimate  = (prompt_t + completion_t) * 0.000030
#      19 # Mlflow audit
# ---> 20 with mlflow.start_run(run_name="rag_request"):
#      21     mlflow.log_param("query",query)
#      22     mlflow.log_metric("latency_ms",latency_ms)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/tracking/fluent.py:644, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     640     user_specified_tags[MLFLOW_RUN_NAME] = run_name
#     642 resolved_tags = context_registry.resolve_tags(user_specified_tags)
# --> 644 active_run_obj = client.create_run(
#     645     experiment_id=exp_id_for_run,
#     646     tags=resolved_tags,
#     647     run_name=run_name,
#     648 )
#     650 # If SGC run resumption is enabled, set the experiment tag mapping
#     651 # SGC job_run_id to this run_id for future run resumption
#     652 if sgc_job_run_id_tag_key:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/tracking/client.py:602, in MlflowClient.create_run(self, experiment_id, start_time, tags, run_name)
#     548 def create_run(
#     549     self,
#     550     experiment_id: str,
#    (...)
#     553     run_name: str | None = None,
#     554 ) -> Run:
#     555     """
#     556     Create a :py:class:`mlflow.entities.Run` object that can be associated with
#     557     metrics, parameters, artifacts, etc.
#    (...)
#     600         status: RUNNING
#     601     """
# --> 602     return self._tracking_client.create_run(experiment_id, start_time, tags, run_name)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/telemetry/track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:186, in TrackingServiceClient.create_run(self, experiment_id, start_time, tags, run_name)
#     181 # Extract user from tags
#     182 # This logic is temporary; the user_id attribute of runs is deprecated and will be removed
#     183 # in a later release.
#     184 user_id = tags.get(MLFLOW_USER, "unknown")
# --> 186 return self.store.create_run(
#     187     experiment_id=experiment_id,
#     188     user_id=user_id,
#     189     start_time=start_time or get_current_time_millis(),
#     190     tags=[RunTag(key, value) for (key, value) in tags.items()],
#     191     run_name=run_name,
#     192 )
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py:776, in SqlAlchemyStore.create_run(self, experiment_id, user_id, start_time, tags, run_name)
#     775 def create_run(self, experiment_id, user_id, start_time, tags, run_name):
# --> 776     with self.ManagedSessionMaker() as session:
#     777         experiment = self.get_experiment(experiment_id)
#     778         self._check_experiment_is_active(experiment)
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/contextlib.py:153, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     151     value = typ()
#     152 try:
# --> 153     self.gen.throw(typ, value, traceback)
#     154 except StopIteration as exc:
#     155     # Suppress StopIteration *unless* it's the same exception that
#     156     # was passed to throw().  This prevents a StopIteration
#     157     # raised inside the "with" statement from being suppressed.
#     158     return exc is not value
#
# File /opt/miniconda3/envs/ml_month3/lib/python3.10/site-packages/mlflow/store/db/utils.py:198, in _get_managed_session_maker.<locals>.make_managed_session()
#     193     session.rollback()
#     194     _logger.exception(
#     195         "SQLAlchemy database error. The following exception is caught.\n%s",
#     196         e,
#     197     )
# --> 198     raise MlflowException(message=e, error_code=TEMPORARILY_UNAVAILABLE) from e
#     199 except sqlalchemy.exc.SQLAlchemyError as e:
#     200     session.rollback()
#
# MlflowException: (raised as a result of Query-invoked autoflush; consider using a session.no_autoflush block if this flush is occurring prematurely)
# (sqlite3.OperationalError) attempt to write a readonly database
# [SQL: INSERT INTO runs (run_uuid, name, source_type, source_name, entry_point_name, user_id, status, start_time, end_time, deleted_time, source_version, lifecycle_stage, artifact_uri, experiment_id) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: ('8d5a4adc38d9455d9d7ab8d46ae7980b', 'rag_request', 'UNKNOWN', '', '', 'spectra', 'RUNNING', 1777999281233, None, None, '', 'active', '/home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlruns/1/8d5a4adc38d9455d9d7ab8d46ae7980b/artifacts', '1')]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# List all existing collections in the persistent path
existing_collections = chroma_client.list_collections()
print(f"Available collections: {[c.name for c in existing_collections]}")
# Out:
# Available collections: ['financial_docs_v2', 'financial_docs', 'financial_docs_v3']

# %%
# TODO 
"""
Current output: "The revenue of Apple in fiscal year 2023 was 383,285."
Target output: "The total net sales of Apple Inc. for fiscal year 2023 (ended September 30, 2023) was $383,285 million."
"""
# Out:
# '\nCurrent output: "The revenue of Apple in fiscal year 2023 was 383,285."\nTarget output: "The total net sales of Apple Inc. for fiscal year 2023 (ended September 30, 2023) was $383,285 million."\n'

# %%
metrics = generate_latest()

# %%
print(metrics)
# Out:
# b'# HELP python_gc_objects_collected_total Objects collected during gc\n# TYPE python_gc_objects_collected_total counter\npython_gc_objects_collected_total{generation="0"} 123004.0\npython_gc_objects_collected_total{generation="1"} 122367.0\npython_gc_objects_collected_total{generation="2"} 14026.0\n# HELP python_gc_objects_uncollectable_total Uncollectable objects found during GC\n# TYPE python_gc_objects_uncollectable_total counter\npython_gc_objects_uncollectable_total{generation="0"} 0.0\npython_gc_objects_uncollectable_total{generation="1"} 0.0\npython_gc_objects_uncollectable_total{generation="2"} 0.0\n# HELP python_gc_collections_total Number of times this generation was collected\n# TYPE python_gc_collections_total counter\npython_gc_collections_total{generation="0"} 2957.0\npython_gc_collections_total{generation="1"} 268.0\npython_gc_collections_total{generation="2"} 13.0\n# HELP python_info Python platform information\n# TYPE python_info gauge\npython_info{implementation="CPython",major="3",minor="10",patchlevel="20",version="3.10.20"} 1.0\n# HELP process_virtual_memory_bytes Virtual memory size in bytes.\n# TYPE process_virtual_memory_bytes gauge\nprocess_virtual_memory_bytes 1.235615744e+010\n# HELP process_resident_memory_bytes Resident memory size in bytes.\n# TYPE process_resident_memory_bytes gauge\nprocess_resident_memory_bytes 1.093603328e+09\n# HELP process_start_time_seconds Start time of the process since unix epoch in seconds.\n# TYPE process_start_time_seconds gauge\nprocess_start_time_seconds 1.77797312087e+09\n# HELP process_cpu_seconds_total Total user and system CPU time spent in seconds.\n# TYPE process_cpu_seconds_total counter\nprocess_cpu_seconds_total 133.2\n# HELP process_open_fds Number of open file descriptors.\n# TYPE process_open_fds gauge\nprocess_open_fds 88.0\n# HELP process_max_fds Maximum number of open file descriptors.\n# TYPE process_max_fds gauge\nprocess_max_fds 4096.0\n# HELP rag_requests_total Total RAG API requests\n# TYPE rag_requests_total counter\nrag_requests_total{endpoint="generate_answer",status_code="error"} 6.0\nrag_requests_total{endpoint="generate_answer",status_code="success"} 1.0\n# HELP rag_requests_created Total RAG API requests\n# TYPE rag_requests_created gauge\nrag_requests_created{endpoint="generate_answer",status_code="error"} 1.777995875746896e+09\nrag_requests_created{endpoint="generate_answer",status_code="success"} 1.777996934273949e+09\n# HELP pipeline_duration_seconds Latency of the RAG pipeline in seconds\n# TYPE pipeline_duration_seconds histogram\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="0.25"} 0.0\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="0.5"} 0.0\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="1.0"} 0.0\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="2.0"} 1.0\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="3.0"} 1.0\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="5.0"} 1.0\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="10.0"} 1.0\npipeline_duration_seconds_bucket{endpoint="generate_answer",le="+Inf"} 1.0\npipeline_duration_seconds_count{endpoint="generate_answer"} 1.0\npipeline_duration_seconds_sum{endpoint="generate_answer"} 1.1298329830169678\n# HELP pipeline_duration_seconds_created Latency of the RAG pipeline in seconds\n# TYPE pipeline_duration_seconds_created gauge\npipeline_duration_seconds_created{endpoint="generate_answer"} 1.7779969342738745e+09\n# HELP active_processing_queries Number of currently processing RAG queries\n# TYPE active_processing_queries gauge\nactive_processing_queries 0.0\n'

# %%
import mlflow
print(mlflow.get_tracking_uri())
# Out:
# sqlite:////home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlflow.db

# %%
with mlflow.start_run(run_name="test_run"):
    mlflow.log_param("test_key", "test_value")
    mlflow.log_metric("test_metric", 42.0)
    print("Run ID:", mlflow.active_run().info.run_id)
# Out:
# Run ID: d9b7fe04d98049f7afe766b56af5612f

# %%
print(mlflow.get_tracking_uri())
# Out:
# sqlite:////home/spectra/Desktop/ml-ai-journey/project3-rag/notebooks/mlflow.db
