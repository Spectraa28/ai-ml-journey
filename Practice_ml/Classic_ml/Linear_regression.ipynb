# %%
# GENERATING A DUMMMY DATASET

# %%
import random
import math 
import numpy as np

# %%
random.seed(42)

# %%
TRUE_W = 3.0
TRUE_BIAS = 7.0
N_SAMPLES = 100

# %%
X = [random.uniform(0,10) for _ in range(N_SAMPLES)]

# %%
y = [TRUE_W * x + TRUE_BIAS + random.gauss(0,2.0) for x in X]

# %% [markdown]
# # LINEAR REGRESSION FROM SCCRATCH WITH GRADIENT DESCENT

# %%
class LinearRegression:
    def __init__(self, learning_rate=0.01):
        self.w = 0.0
        self.b = 0.0
        self.lr = learning_rate
        self.cost_history = []

    def predict(self, X):
        return [self.w * x + self.b for x in X]

    def compute_cost(self, X, y):
        predictions = self.predict(X)
        n = len(y)
        cost = sum((pred - actual) ** 2 for pred, actual in zip(predictions, y)) / n
        return cost

    def compute_gradients(self, X, y):
        predictions = self.predict(X)
        n = len(y)
        dw = (2 / n) * sum((pred - actual) * x for pred, actual, x in zip(predictions, y, X))
        db = (2 / n) * sum(pred - actual for pred, actual in zip(predictions, y))
        return dw, db

    def fit(self, X, y, epochs=1000, print_every=200):
        for epoch in range(epochs):
            dw, db = self.compute_gradients(X, y)
            self.w -= self.lr * dw
            self.b -= self.lr * db
            cost = self.compute_cost(X, y)
            self.cost_history.append(cost)
            if epoch % print_every == 0:
                print(f"  Epoch {epoch:4d} | Cost: {cost:.4f} | w: {self.w:.4f} | b: {self.b:.4f}")
        return self

    def r_squared(self, X, y):
        predictions = self.predict(X)
        y_mean = sum(y) / len(y)
        ss_res = sum((actual - pred) ** 2 for actual, pred in zip(y, predictions))
        ss_tot = sum((actual - y_mean) ** 2 for actual in y)
        return 1 - (ss_res / ss_tot)

# %%
print("=== Training Linear Regression (Gradient Descent) ===")
model = LinearRegression(learning_rate=0.005)
model.fit(X, y, epochs=1000, print_every=200)
print(f"\nLearned: y = {model.w:.4f}x + {model.b:.4f}")
print(f"True:    y = {TRUE_W}x + {TRUE_BIAS}")
print(f"R-squared: {model.r_squared(X, y):.4f}")
# Out:
# === Training Linear Regression (Gradient Descent) ===
#   Epoch    0 | Cost: 263.0919 | w: 1.3073 | b: 0.2174
#   Epoch  200 | Cost: 7.4251 | w: 3.6454 | b: 3.2610
#   Epoch  400 | Cost: 4.9453 | w: 3.4099 | b: 4.8006
#   Epoch  600 | Cost: 4.0920 | w: 3.2717 | b: 5.7038
#   Epoch  800 | Cost: 3.7984 | w: 3.1906 | b: 6.2336
#
# Learned: y = 3.1433x + 6.5432
# True:    y = 3.0x + 7.0
# R-squared: 0.9566
